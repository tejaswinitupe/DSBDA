# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv("StudentsPerformancenew.csv")

# %%
d.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 3                    none        47.0            NaN           44.0
# 4                    none        76.0           78.0           75.0

# %%
d.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed        88.0           99.0           95.0
# 996                    none        62.0           55.0           55.0
# 997               completed        59.0           71.0           65.0
# 998               completed        68.0           78.0           77.0
# 999                    none        77.0           86.0           86.0

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   999 non-null    float64
#  6   reading score                999 non-null    float64
#  7   writing score                997 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 43.0+ KB

# %%
d.describe()
# Out:
#        math score  reading score  writing score
# count  999.000000     999.000000     997.000000
# mean    66.067067      69.181181      68.097292
# std     15.154796      14.602420      15.181947
# min      0.000000      17.000000      10.000000
# 25%     57.000000      59.000000      58.000000
# 50%     66.000000      70.000000      69.000000
# 75%     77.000000      79.000000      79.000000
# max    100.000000     100.000000     100.000000

# %%
d.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                      999
# reading score                   999
# writing score                   997
# dtype: int64

# %%
d.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     1
# reading score                  1
# writing score                  3
# dtype: int64

# %%
x=d['math score'].mean()
d['math score'].fillna(x,inplace=True)

# %%
d.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  1
# writing score                  3
# dtype: int64

# %%
d['reading score']
# Out:
# 0      72.0
# 1      90.0
# 2      95.0
# 3       NaN
# 4      78.0
#        ...
# 995    99.0
# 996    55.0
# 997    71.0
# 998    78.0
# 999    86.0
# Name: reading score, Length: 1000, dtype: float64

# %%
d['reading score'].interpolate(inplace=True)

# %% [markdown]
# # dropping missing values

# %%
d.dropna(inplace=True)

# %%
d.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# # Check for Outliers

# %% [markdown]
# # Detecting Outlier using Box Plot

# %%
plt.figure(figsize=(10,8))
d.boxplot()
plt.show()

# %% [markdown]
# # Data Transformation

# %% [markdown]
# # 1) Transformation using log

# %%
sns.pairplot(d)
plt.show()

# %%
new_dataset = pd.DataFrame()
new_dataset['math log'] = np.log10(d['math score'])
new_dataset['reading log'] = np.log10(d['reading score'])
new_dataset['writing log'] = np.log10(d['writing score'])
new_dataset.head()
# Out:
# c:\users\dell\pycharmprojects\panda\venv\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    math log  reading log  writing log
# 0  1.857332     1.857332     1.869232
# 1  1.838849     1.954243     1.944483
# 2  1.954243     1.977724     1.968483
# 3  1.672098     1.937016     1.643453
# 4  1.880814     1.892095     1.875061

# %%
sns.pairplot(new_dataset)
